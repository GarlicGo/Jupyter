# %%
#!/usr/bin/env python
# -*- coding: UTF-8 -*-
"""
@File    ：PressureLocationProcess.py
@Author  ：zhaolin
@Date    ：2022/3/31 14:35
"""
from math import tan

import cv2
import numpy as np
import matplotlib.pyplot as plt

def cv_show(img):
    cv2.imshow('cv_show', img)
    cv2.waitKey(0)  # 等待时间，毫秒级，0标示按任意键终止
    cv2.destroyAllWindows()
    cv2.waitKey(1)  # 解决mac中窗口不关闭的问题
    
def showImages(images, titles = [''], size = [1, 1], BGR = False):
    for i in range(len(images)):
        plt.subplot(size[0], size[1], i + 1)
        showImage = images[i]
        if (BGR):
            b,g,r = cv2.split(images[i])
            showImage = cv2.merge([r,g,b])
        plt.imshow(showImage ,'gray')
        plt.title(titles[i])
        plt.xticks([]), plt.yticks([])

# %%
reduction = cv2.imread(
    '/Users/zhouxinyu/Code/Python/jupyter/Project/ZF/压线筒污染/图-test/reduction.png', cv2.IMREAD_COLOR)
reduction = cv2.cvtColor(reduction, cv2.COLOR_BGR2GRAY)
img = cv2.imread(
    '/Users/zhouxinyu/Code/Python/jupyter/Project/ZF/压线筒污染/图片/压线筒污染 (5).tif', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
reductionFlated = reduction.ravel()
avgReduction = int(1.2 * (sum(reductionFlated)/len(reductionFlated)))
avgReductionBG = np.array(
    [[avgReduction for col in range(img.shape[1])] for row in range(img.shape[0])], dtype=np.uint8
)
out = np.array(
    [[0 for col in range(img.shape[1])] for row in range(img.shape[0])]
)
black = np.array(
    [[0 for col in range(img.shape[1])] for row in range(img.shape[0])]
)

showImages([img, reduction], ['', ''], [2, 1])

# %%
avgReductionBG
# Out:
# array([[151, 151, 151, ..., 151, 151, 151],
#        [151, 151, 151, ..., 151, 151, 151],
#        [151, 151, 151, ..., 151, 151, 151],
#        ...,
#        [151, 151, 151, ..., 151, 151, 151],
#        [151, 151, 151, ..., 151, 151, 151],
#        [151, 151, 151, ..., 151, 151, 151]])

# %%
# out = np.array()
img2 = cv2.add(img, img)
img2 = cv2.add(img, img)
# img - avgReductionBG
showImages([img, img2], ['', ''], [2, 1])

# %%
cv_show(img)

# %%
test1 = cv2.add(img, img)
showImages([test1])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /Users/zhouxinyu/Code/Python/jupyter/Project/ZF/压线筒污染/cha.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/zhouxinyu/Code/Python/jupyter/Project/ZF/%E5%8E%8B%E7%BA%BF%E7%AD%92%E6%B1%A1%E6%9F%93/cha.ipynb#ch0000004?line=0'>1</a> test1 = cv2.add(reduction, img)
#       <a href='vscode-notebook-cell:/Users/zhouxinyu/Code/Python/jupyter/Project/ZF/%E5%8E%8B%E7%BA%BF%E7%AD%92%E6%B1%A1%E6%9F%93/cha.ipynb#ch0000004?line=1'>2</a> showImages([test1])
#
# error: OpenCV(4.5.5) /Users/runner/work/opencv-python/opencv-python/opencv/modules/core/src/arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
img
# Out:
# array([[147, 139, 137, ..., 191, 191, 189],
#        [142, 143, 137, ..., 191, 190, 190],
#        [143, 149, 145, ..., 191, 188, 191],
#        ...,
#        [146, 144, 141, ..., 165, 160, 166],
#        [146, 147, 141, ..., 166, 167, 171],
#        [141, 140, 138, ..., 169, 168, 170]], dtype=uint8)
